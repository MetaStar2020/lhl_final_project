# %% [markdown]
# # Imports (TODO: create requirements.py)

# %%
# !pip install pytictoc

# %% [markdown]
# # Getting Repo from GitHub

# %%
# %cd /content/drive/MyDrive/Lighthouse - Data Science/Final Project/GitHub/
# Out:
# /content/drive/MyDrive/Lighthouse - Data Science/Final Project/GitHub

# %%
username = 'MetaStar2020'
repository = 'lhl_final_project'
git_token = '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'

# %%
# !git clone https://{git_token}@github.com/{username}/{repository}
# Out:
# Cloning into 'lhl_final_project'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 6 (delta 0), reused 3 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), done.

# %%
# %cd {repository}
# Out:
# /content/drive/MyDrive/Lighthouse - Data Science/Final Project/GitHub/lhl_final_project

# %%
# %ls -a
# Out:
# .git/  README.md

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	lhl_final_project.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %% [markdown]
# # Downloading ASL Youtubes for the DataSet

# %%
# !pip install --upgrade youtube-dl
